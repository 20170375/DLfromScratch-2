# %% [markdown]
# ## CHAPTER 4: word2vec 속도 개선

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 4.1 word2vec 개선 ①
# + **입력층의 원핫 표현**과 **가중치 행렬 W<sub>in</sub>**의 곱 계산

# %%
import numpy as np

class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None
    
    def forward(self, idx):
        W, = self.grads
        self.idx = idx
        out = W[idx]
        return out
    
    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0
        
        for i, word_id in enumerate(self.idx):
            dW[word_id] += dout[i]
        
        return None

# %% [markdown]
# ### 4.2 word2vec 개선 ②
# + **은닉층**과 **가중치 행렬 W<sub>out</sub>**의 곱
# + **Softmax 계층**의 계산

# %%
class EmbeddingDot:
    def __init__(self, W):
        self.embed = Embedding(W)
        self.params = self.embed.params
        self.grads = self.embed.grads
        self.cache = None
    
    def forward(self, h, idx):
        target_W = self.embed.forward(idx)
        out = np.sum(target_W * h, axis=1)
        
        self.cache = (h, target_W)
        return out
    
    def backward(self, dout):
        h, target_W = self.cache
        dout = dout.reshape(dout.shape[0], 1)
        
        dtarget_W = dout * h
        self.embed.backward(dtarget_W)
        dh = dout * target_W
        return dh

# %% [markdown]
# #### 4.2.5 네거티브 샘플링
#
# 긍정적 예를 타깃으로 한 경우의 손실을 구하고, 그와 동시에 부정적 예를 몇 개 샘플링하여 마찬가지로 손실을 구합니다.
#
# 그리고 각각의 데이터의 손실을 더한 값을 최종 손실로 합니다.

# %% [markdown]
# #### 4.2.7 네거티브 샘플링 구현

# %%
import sys
sys.path.append('exam_code')
from ch04.negative_sampling_layer import EmbeddingDot, UnigramSampler
from common.layers import SigmoidWithLoss

class NegativeSamplingLoss:
    def __init__(self, W, corpus, power=0.75, sample_size=5):
        self.sample_size = sample_size
        self.sampler = UnigramSampler(corpus, power, sample_size)
        self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size+1)]
        self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size+1)]
        
        self.params, self.grads = [], []
        for layer in self.embed_dot_layers:
            self.params += layer.params
            self.grads  += layer.grads
        
    def forward(self, h, target):
        batch_size = target.shape[0]
        negative_sample = self.sampler.get_negative_sample(target)
        
        # 긍정적 예 순전파
        score = self.embed_dot_layers[0].forward(h, target)
        correct_label = np.ones(batch_size, dtype=np.int32)
        loss = self.loss_layers[0].forward(score, correct_label)
        
        # 부정적 예 순전파
        negative_label = np.zeros(batch_size, dtype=np.int32)
        for i in range(self.sample_size):
            negative_target = negative_sample[:, i]
            score = self.embed_dot_layers[i+1].forward(h, negative_target)
            loss += self.loss_layers[i+1].forward(score, negative_label)
        return loss
    
    def backward(self, dout=1):
        dh = 0
        for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
            dscore = l0.backward(dout)
            dh += l1.backward(dscore)
        return dh

# %% [markdown]
# ### 4.3 개선판 word2vec 학습

# %% [markdown]
# #### 4.3.1 CBOW 모델 구현

# %%
import sys
sys.path.append('exam_code')
from common.layers import Embedding
from ch04.negative_sampling_layer import NegativeSamplingLoss

class CBOW:
    def __init__(self, vocab_size, hidden_size, window_size, corpus):
        V, H = vocab_size, hidden_size
        
        # 가중치 초기화
        W_in  = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(V, H).astype('f')
        
        # 계층 생성
        self.in_layers = []
        for i in range(2 * window_size):
            layer = Embedding(W_in)
            self.in_layers.append(layer)
        self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)
        
        # 모든 가중치와 기울기를 배열에 모은다.
        layers = self.in_layers + [self.ns_loss]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads  += layer.grads
        
        # 인스턴스 변수에 단어의 분산 표현을 저장한다.
        self.word_vecs = W_in
        
    def forward(self, contexts, target):
        h = 0
        for i, layer in enumerate(self.in_layers):
            h += layer.forward(contexts[:, i])
        h *= 1 / len(self.in_layers)
        loss = self.ns_loss.forward(h, target)
        return loss
        
    def backward(self, dout=1):
        dout = self.ns_loss.backward(dout)
        dout *= 1 / len(self.in_layers)
        for layer in self,in_layers:
            layer.backward(dout)
        return None

# %% [markdown]
# #### 4.3.2 CBOW 모델 학습 코드

# %%
import sys
sys.path.append('exam_code')
import numpy as np
import pickle
from common.trainer import Trainer
from common.optimizer import Adam
from ch04.cbow import CBOW
from common.util import create_contexts_target
from dataset import ptb

# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size  = 100
max_epoch   = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

contexts, target = create_contexts_target(corpus, window_size)

# 모델 등 생성
model     = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer   = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중에 사용할 수 있도록 필요한 데이터 저장
word_vecs = model.word_vecs
params = {}
params['word_vecs']  = word_vecs.astype('np.float16')
params['word_to_id'] = word_to_id
params['id_to_word'] = id_to_word

pkl_file = 'cbow_params.pkl'
with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# | 에폭 1 |  반복 1 / 9295 | 시간 0[s] | 손실 4.16
# | 에폭 1 |  반복 21 / 9295 | 시간 1[s] | 손실 4.16
# | 에폭 1 |  반복 41 / 9295 | 시간 3[s] | 손실 4.15
# | 에폭 1 |  반복 61 / 9295 | 시간 4[s] | 손실 4.12
# | 에폭 1 |  반복 81 / 9295 | 시간 6[s] | 손실 4.05
# | 에폭 1 |  반복 101 / 9295 | 시간 7[s] | 손실 3.93
# | 에폭 1 |  반복 121 / 9295 | 시간 9[s] | 손실 3.77
# | 에폭 1 |  반복 141 / 9295 | 시간 10[s] | 손실 3.62
# | 에폭 1 |  반복 161 / 9295 | 시간 12[s] | 손실 3.50
# | 에폭 1 |  반복 181 / 9295 | 시간 13[s] | 손실 3.35
# | 에폭 1 |  반복 201 / 9295 | 시간 15[s] | 손실 3.24
# | 에폭 1 |  반복 221 / 9295 | 시간 16[s] | 손실 3.17
# | 에폭 1 |  반복 241 / 9295 | 시간 18[s] | 손실 3.08
# | 에폭 1 |  반복 261 / 9295 | 시간 19[s] | 손실 3.03
# | 에폭 1 |  반복 281 / 9295 | 시간 21[s] | 손실 2.97
# | 에폭 1 |  반복 301 / 9295 | 시간 22[s] | 손실 2.90
# | 에폭 1 |  반복 321 / 9295 | 시간 24[s] | 손실 2.87
# | 에폭 1 |  반복 341 / 9295 | 시간 25[s] | 손실 2.83
# | 에폭 1 |  반복 361 / 9295 | 시간 27[s] | 손실 2.82
# | 에폭 1 |  반복 381 / 9295 | 시간 28[s] | 손실 2.78
# | 에폭 1 |  반복 401 / 9295 | 시간 30[s] | 손실 2.75
# | 에폭 1 |  반복 421 / 9295 | 시간 31[s] | 손실 2.74
# | 에폭 1 |  반복 441 / 9295 | 시간 32[s] | 손실 2.73
# | 에폭 1 |  반복 461 / 9295 | 시간 34[s] | 손실 2.68
# | 에폭 1 |  반복 481 / 9295 | 시간 36[s] | 손실 2.72
# | 에폭 1 |  반복 501 / 9295 | 시간 37[s] | 손실 2.70
# | 에폭 1 |  반복 521 / 9295 | 시간 38[s] | 손실 2.68
# | 에폭 1 |  반복 541 / 9295 | 시간 40[s] | 손실 2.66
# | 에폭 1 |  반복 561 / 9295 | 시간 41[s] | 손실 2.71
# | 에폭 1 |  반복 581 / 9295 | 시간 43[s] | 손실 2.65
# | 에폭 1 |  반복 601 / 9295 | 시간 44[s] | 손실 2.67
# | 에폭 1 |  반복 621 / 9295 | 시간 46[s] | 손실 2.64
# | 에폭 1 |  반복 641 / 9295 | 시간 47[s] | 손실 2.64
# | 에폭 1 |  반복 661 / 9295 | 시간 49[s] | 손실 2.64
# | 에폭 1 |  반복 681 / 9295 | 시간 50[s] | 손실 2.63
# | 에폭 1 |  반복 701 / 9295 | 시간 51[s] | 손실 2.61
# | 에폭 1 |  반복 721 / 9295 | 시간 53[s] | 손실 2.63
# | 에폭 1 |  반복 741 / 9295 | 시간 54[s] | 손실 2.62
# | 에폭 1 |  반복 761 / 9295 | 시간 56[s] | 손실 2.60
# | 에폭 1 |  반복 781 / 9295 | 시간 57[s] | 손실 2.61
# | 에폭 1 |  반복 801 / 9295 | 시간 59[s] | 손실 2.60
# | 에폭 1 |  반복 821 / 9295 | 시간 60[s] | 손실 2.59
# | 에폭 1 |  반복 841 / 9295 | 시간 62[s] | 손실 2.61
# | 에폭 1 |  반복 861 / 9295 | 시간 63[s] | 손실 2.58
# | 에폭 1 |  반복 881 / 9295 | 시간 64[s] | 손실 2.60
# | 에폭 1 |  반복 901 / 9295 | 시간 66[s] | 손실 2.57
# | 에폭 1 |  반복 921 / 9295 | 시간 67[s] | 손실 2.58
# | 에폭 1 |  반복 941 / 9295 | 시간 69[s] | 손실 2.58
# | 에폭 1 |  반복 961 / 9295 | 시간 70[s] | 손실 2.57
# | 에폭 1 |  반복 981 / 9295 | 시간 72[s] | 손실 2.56
# | 에폭 1 |  반복 1001 / 9295 | 시간 73[s] | 손실 2.54
# | 에폭 1 |  반복 1021 / 9295 | 시간 74[s] | 손실 2.55
# | 에폭 1 |  반복 1041 / 9295 | 시간 76[s] | 손실 2.58
# | 에폭 1 |  반복 1061 / 9295 | 시간 77[s] | 손실 2.56
# | 에폭 1 |  반복 1081 / 9295 | 시간 79[s] | 손실 2.55
# | 에폭 1 |  반복 1101 / 9295 | 시간 80[s] | 손실 2.53
# | 에폭 1 |  반복 1121 / 9295 | 시간 82[s] | 손실 2.55
# | 에폭 1 |  반복 1141 / 9295 | 시간 83[s] | 손실 2.52
# | 에폭 1 |  반복 1161 / 9295 | 시간 85[s] | 손실 2.54
# | 에폭 1 |  반복 1181 / 9295 | 시간 86[s] | 손실 2.55
# | 에폭 1 |  반복 1201 / 9295 | 시간 87[s] | 손실 2.55
# | 에폭 1 |  반복 1221 / 9295 | 시간 89[s] | 손실 2.53
# | 에폭 1 |  반복 1241 / 9295 | 시간 90[s] | 손실 2.52
# | 에폭 1 |  반복 1261 / 9295 | 시간 92[s] | 손실 2.54
# | 에폭 1 |  반복 1281 / 9295 | 시간 93[s] | 손실 2.54
# | 에폭 1 |  반복 1301 / 9295 | 시간 95[s] | 손실 2.54
# | 에폭 1 |  반복 1321 / 9295 | 시간 96[s] | 손실 2.55
# | 에폭 1 |  반복 1341 / 9295 | 시간 98[s] | 손실 2.52
# | 에폭 1 |  반복 1361 / 9295 | 시간 99[s] | 손실 2.55
# | 에폭 1 |  반복 1381 / 9295 | 시간 101[s] | 손실 2.48
# | 에폭 1 |  반복 1401 / 9295 | 시간 102[s] | 손실 2.53
# | 에폭 1 |  반복 1421 / 9295 | 시간 103[s] | 손실 2.52
# | 에폭 1 |  반복 1441 / 9295 | 시간 105[s] | 손실 2.54
# | 에폭 1 |  반복 1461 / 9295 | 시간 106[s] | 손실 2.52
# | 에폭 1 |  반복 1481 / 9295 | 시간 108[s] | 손실 2.50
# | 에폭 1 |  반복 1501 / 9295 | 시간 109[s] | 손실 2.50
# | 에폭 1 |  반복 1521 / 9295 | 시간 111[s] | 손실 2.49
# | 에폭 1 |  반복 1541 / 9295 | 시간 112[s] | 손실 2.49
# | 에폭 1 |  반복 1561 / 9295 | 시간 114[s] | 손실 2.54
# | 에폭 1 |  반복 1581 / 9295 | 시간 115[s] | 손실 2.51
# | 에폭 1 |  반복 1601 / 9295 | 시간 116[s] | 손실 2.50
# | 에폭 1 |  반복 1621 / 9295 | 시간 118[s] | 손실 2.51
# | 에폭 1 |  반복 1641 / 9295 | 시간 119[s] | 손실 2.50
# | 에폭 1 |  반복 1661 / 9295 | 시간 121[s] | 손실 2.51
# | 에폭 1 |  반복 1681 / 9295 | 시간 122[s] | 손실 2.52
# | 에폭 1 |  반복 1701 / 9295 | 시간 124[s] | 손실 2.50
# | 에폭 1 |  반복 1721 / 9295 | 시간 125[s] | 손실 2.51
# | 에폭 1 |  반복 1741 / 9295 | 시간 127[s] | 손실 2.46
# | 에폭 1 |  반복 1761 / 9295 | 시간 128[s] | 손실 2.50
# | 에폭 1 |  반복 1781 / 9295 | 시간 129[s] | 손실 2.49
# | 에폭 1 |  반복 1801 / 9295 | 시간 131[s] | 손실 2.46
# | 에폭 1 |  반복 1821 / 9295 | 시간 132[s] | 손실 2.50
# | 에폭 1 |  반복 1841 / 9295 | 시간 134[s] | 손실 2.48
# | 에폭 1 |  반복 1861 / 9295 | 시간 135[s] | 손실 2.53
# | 에폭 1 |  반복 1881 / 9295 | 시간 137[s] | 손실 2.48
# | 에폭 1 |  반복 1901 / 9295 | 시간 138[s] | 손실 2.49
# | 에폭 1 |  반복 1921 / 9295 | 시간 140[s] | 손실 2.49
# | 에폭 1 |  반복 1941 / 9295 | 시간 141[s] | 손실 2.44
# | 에폭 1 |  반복 1961 / 9295 | 시간 142[s] | 손실 2.50
# | 에폭 1 |  반복 1981 / 9295 | 시간 144[s] | 손실 2.49
# | 에폭 1 |  반복 2001 / 9295 | 시간 145[s] | 손실 2.52
# | 에폭 1 |  반복 2021 / 9295 | 시간 147[s] | 손실 2.52
# | 에폭 1 |  반복 2041 / 9295 | 시간 148[s] | 손실 2.49
# | 에폭 1 |  반복 2061 / 9295 | 시간 150[s] | 손실 2.50
# | 에폭 1 |  반복 2081 / 9295 | 시간 151[s] | 손실 2.47
# | 에폭 1 |  반복 2101 / 9295 | 시간 153[s] | 손실 2.47
# | 에폭 1 |  반복 2121 / 9295 | 시간 154[s] | 손실 2.48
# | 에폭 1 |  반복 2141 / 9295 | 시간 156[s] | 손실 2.48
# | 에폭 1 |  반복 2161 / 9295 | 시간 157[s] | 손실 2.47
# | 에폭 1 |  반복 2181 / 9295 | 시간 159[s] | 손실 2.51
# | 에폭 1 |  반복 2201 / 9295 | 시간 160[s] | 손실 2.47
# | 에폭 1 |  반복 2221 / 9295 | 시간 161[s] | 손실 2.48
# | 에폭 1 |  반복 2241 / 9295 | 시간 163[s] | 손실 2.48
# | 에폭 1 |  반복 2261 / 9295 | 시간 164[s] | 손실 2.49
# | 에폭 1 |  반복 2281 / 9295 | 시간 166[s] | 손실 2.48
# | 에폭 1 |  반복 2301 / 9295 | 시간 167[s] | 손실 2.46
# | 에폭 1 |  반복 2321 / 9295 | 시간 169[s] | 손실 2.47
# | 에폭 1 |  반복 2341 / 9295 | 시간 170[s] | 손실 2.53
# | 에폭 1 |  반복 2361 / 9295 | 시간 172[s] | 손실 2.49
# | 에폭 1 |  반복 2381 / 9295 | 시간 173[s] | 손실 2.47
# | 에폭 1 |  반복 2401 / 9295 | 시간 174[s] | 손실 2.46
# | 에폭 1 |  반복 2421 / 9295 | 시간 176[s] | 손실 2.47
# | 에폭 1 |  반복 2441 / 9295 | 시간 177[s] | 손실 2.47
# | 에폭 1 |  반복 2461 / 9295 | 시간 179[s] | 손실 2.46
# | 에폭 1 |  반복 2481 / 9295 | 시간 180[s] | 손실 2.50
# | 에폭 1 |  반복 2501 / 9295 | 시간 182[s] | 손실 2.48
# | 에폭 1 |  반복 2521 / 9295 | 시간 183[s] | 손실 2.46
# | 에폭 1 |  반복 2541 / 9295 | 시간 185[s] | 손실 2.45
# | 에폭 1 |  반복 2561 / 9295 | 시간 186[s] | 손실 2.45
# | 에폭 1 |  반복 2581 / 9295 | 시간 188[s] | 손실 2.48
# | 에폭 1 |  반복 2601 / 9295 | 시간 189[s] | 손실 2.48
# | 에폭 1 |  반복 2621 / 9295 | 시간 191[s] | 손실 2.45
# | 에폭 1 |  반복 2641 / 9295 | 시간 192[s] | 손실 2.45
# | 에폭 1 |  반복 2661 / 9295 | 시간 194[s] | 손실 2.47
# | 에폭 1 |  반복 2681 / 9295 | 시간 195[s] | 손실 2.46
# | 에폭 1 |  반복 2701 / 9295 | 시간 197[s] | 손실 2.45
# | 에폭 1 |  반복 2721 / 9295 | 시간 198[s] | 손실 2.46
# | 에폭 1 |  반복 2741 / 9295 | 시간 199[s] | 손실 2.49
# | 에폭 1 |  반복 2761 / 9295 | 시간 201[s] | 손실 2.45
# | 에폭 1 |  반복 2781 / 9295 | 시간 202[s] | 손실 2.47
# | 에폭 1 |  반복 2801 / 9295 | 시간 204[s] | 손실 2.49
# | 에폭 1 |  반복 2821 / 9295 | 시간 205[s] | 손실 2.47
# | 에폭 1 |  반복 2841 / 9295 | 시간 207[s] | 손실 2.42
# | 에폭 1 |  반복 2861 / 9295 | 시간 208[s] | 손실 2.45
# | 에폭 1 |  반복 2881 / 9295 | 시간 209[s] | 손실 2.45
# | 에폭 1 |  반복 2901 / 9295 | 시간 211[s] | 손실 2.45
# | 에폭 1 |  반복 2921 / 9295 | 시간 212[s] | 손실 2.46
# | 에폭 1 |  반복 2941 / 9295 | 시간 214[s] | 손실 2.47
# | 에폭 1 |  반복 2961 / 9295 | 시간 215[s] | 손실 2.45
# | 에폭 1 |  반복 2981 / 9295 | 시간 217[s] | 손실 2.42
# | 에폭 1 |  반복 3001 / 9295 | 시간 218[s] | 손실 2.48
# | 에폭 1 |  반복 3021 / 9295 | 시간 220[s] | 손실 2.46
# | 에폭 1 |  반복 3041 / 9295 | 시간 221[s] | 손실 2.43
# | 에폭 1 |  반복 3061 / 9295 | 시간 222[s] | 손실 2.47
# | 에폭 1 |  반복 3081 / 9295 | 시간 224[s] | 손실 2.47
# | 에폭 1 |  반복 3101 / 9295 | 시간 225[s] | 손실 2.42
# | 에폭 1 |  반복 3121 / 9295 | 시간 227[s] | 손실 2.46
# | 에폭 1 |  반복 3141 / 9295 | 시간 228[s] | 손실 2.42
# | 에폭 1 |  반복 3161 / 9295 | 시간 230[s] | 손실 2.44
# | 에폭 1 |  반복 3181 / 9295 | 시간 231[s] | 손실 2.44
# | 에폭 1 |  반복 3201 / 9295 | 시간 232[s] | 손실 2.44
# | 에폭 1 |  반복 3221 / 9295 | 시간 234[s] | 손실 2.44
# | 에폭 1 |  반복 3241 / 9295 | 시간 235[s] | 손실 2.44
# | 에폭 1 |  반복 3261 / 9295 | 시간 237[s] | 손실 2.43
# | 에폭 1 |  반복 3281 / 9295 | 시간 238[s] | 손실 2.44
# | 에폭 1 |  반복 3301 / 9295 | 시간 240[s] | 손실 2.46
# | 에폭 1 |  반복 3321 / 9295 | 시간 241[s] | 손실 2.40
# | 에폭 1 |  반복 3341 / 9295 | 시간 242[s] | 손실 2.42
# | 에폭 1 |  반복 3361 / 9295 | 시간 244[s] | 손실 2.43
# | 에폭 1 |  반복 3381 / 9295 | 시간 245[s] | 손실 2.44
# | 에폭 1 |  반복 3401 / 9295 | 시간 247[s] | 손실 2.42
# | 에폭 1 |  반복 3421 / 9295 | 시간 248[s] | 손실 2.44
# | 에폭 1 |  반복 3441 / 9295 | 시간 250[s] | 손실 2.43
# | 에폭 1 |  반복 3461 / 9295 | 시간 251[s] | 손실 2.42
# | 에폭 1 |  반복 3481 / 9295 | 시간 252[s] | 손실 2.45
# | 에폭 1 |  반복 3501 / 9295 | 시간 254[s] | 손실 2.40
# | 에폭 1 |  반복 3521 / 9295 | 시간 255[s] | 손실 2.43
# | 에폭 1 |  반복 3541 / 9295 | 시간 257[s] | 손실 2.42
# | 에폭 1 |  반복 3561 / 9295 | 시간 258[s] | 손실 2.42
# | 에폭 1 |  반복 3581 / 9295 | 시간 260[s] | 손실 2.43
# | 에폭 1 |  반복 3601 / 9295 | 시간 261[s] | 손실 2.41
# | 에폭 1 |  반복 3621 / 9295 | 시간 262[s] | 손실 2.41
# | 에폭 1 |  반복 3641 / 9295 | 시간 264[s] | 손실 2.41
# | 에폭 1 |  반복 3661 / 9295 | 시간 265[s] | 손실 2.38
# | 에폭 1 |  반복 3681 / 9295 | 시간 267[s] | 손실 2.43
# | 에폭 1 |  반복 3701 / 9295 | 시간 268[s] | 손실 2.43
# | 에폭 1 |  반복 3721 / 9295 | 시간 270[s] | 손실 2.42
# | 에폭 1 |  반복 3741 / 9295 | 시간 271[s] | 손실 2.43
# | 에폭 1 |  반복 3761 / 9295 | 시간 272[s] | 손실 2.38
# | 에폭 1 |  반복 3781 / 9295 | 시간 274[s] | 손실 2.44
# | 에폭 1 |  반복 3801 / 9295 | 시간 275[s] | 손실 2.40
# | 에폭 1 |  반복 3821 / 9295 | 시간 277[s] | 손실 2.39
# | 에폭 1 |  반복 3841 / 9295 | 시간 278[s] | 손실 2.42
# | 에폭 1 |  반복 3861 / 9295 | 시간 280[s] | 손실 2.43
# | 에폭 1 |  반복 3881 / 9295 | 시간 281[s] | 손실 2.41
# | 에폭 1 |  반복 3901 / 9295 | 시간 282[s] | 손실 2.39
# | 에폭 1 |  반복 3921 / 9295 | 시간 284[s] | 손실 2.39
# | 에폭 1 |  반복 3941 / 9295 | 시간 285[s] | 손실 2.39
# | 에폭 1 |  반복 3961 / 9295 | 시간 287[s] | 손실 2.38
# | 에폭 1 |  반복 3981 / 9295 | 시간 288[s] | 손실 2.40
# | 에폭 1 |  반복 4001 / 9295 | 시간 290[s] | 손실 2.38
# | 에폭 1 |  반복 4021 / 9295 | 시간 291[s] | 손실 2.40
# | 에폭 1 |  반복 4041 / 9295 | 시간 292[s] | 손실 2.42
# | 에폭 1 |  반복 4061 / 9295 | 시간 294[s] | 손실 2.42
# | 에폭 1 |  반복 4081 / 9295 | 시간 295[s] | 손실 2.46
# | 에폭 1 |  반복 4101 / 9295 | 시간 297[s] | 손실 2.38
# | 에폭 1 |  반복 4121 / 9295 | 시간 298[s] | 손실 2.41
# | 에폭 1 |  반복 4141 / 9295 | 시간 300[s] | 손실 2.39
# | 에폭 1 |  반복 4161 / 9295 | 시간 301[s] | 손실 2.42
# | 에폭 1 |  반복 4181 / 9295 | 시간 303[s] | 손실 2.38
# | 에폭 1 |  반복 4201 / 9295 | 시간 304[s] | 손실 2.41
# | 에폭 1 |  반복 4221 / 9295 | 시간 306[s] | 손실 2.40
# | 에폭 1 |  반복 4241 / 9295 | 시간 307[s] | 손실 2.39
# | 에폭 1 |  반복 4261 / 9295 | 시간 308[s] | 손실 2.38
# | 에폭 1 |  반복 4281 / 9295 | 시간 310[s] | 손실 2.39
# | 에폭 1 |  반복 4301 / 9295 | 시간 311[s] | 손실 2.39
# | 에폭 1 |  반복 4321 / 9295 | 시간 313[s] | 손실 2.41
# | 에폭 1 |  반복 4341 / 9295 | 시간 314[s] | 손실 2.40
# | 에폭 1 |  반복 4361 / 9295 | 시간 316[s] | 손실 2.41
# | 에폭 1 |  반복 4381 / 9295 | 시간 317[s] | 손실 2.39
# | 에폭 1 |  반복 4401 / 9295 | 시간 318[s] | 손실 2.39
# | 에폭 1 |  반복 4421 / 9295 | 시간 320[s] | 손실 2.37
# | 에폭 1 |  반복 4441 / 9295 | 시간 321[s] | 손실 2.37
# | 에폭 1 |  반복 4461 / 9295 | 시간 323[s] | 손실 2.40
# | 에폭 1 |  반복 4481 / 9295 | 시간 324[s] | 손실 2.38
# | 에폭 1 |  반복 4501 / 9295 | 시간 326[s] | 손실 2.38
# | 에폭 1 |  반복 4521 / 9295 | 시간 327[s] | 손실 2.36
# | 에폭 1 |  반복 4541 / 9295 | 시간 329[s] | 손실 2.36
# | 에폭 1 |  반복 4561 / 9295 | 시간 330[s] | 손실 2.38
# | 에폭 1 |  반복 4581 / 9295 | 시간 331[s] | 손실 2.39
# | 에폭 1 |  반복 4601 / 9295 | 시간 333[s] | 손실 2.40
# | 에폭 1 |  반복 4621 / 9295 | 시간 334[s] | 손실 2.39
# | 에폭 1 |  반복 4641 / 9295 | 시간 336[s] | 손실 2.36
# | 에폭 1 |  반복 4661 / 9295 | 시간 337[s] | 손실 2.37
# | 에폭 1 |  반복 4681 / 9295 | 시간 339[s] | 손실 2.41
# | 에폭 1 |  반복 4701 / 9295 | 시간 340[s] | 손실 2.37
# | 에폭 1 |  반복 4721 / 9295 | 시간 342[s] | 손실 2.37
# | 에폭 1 |  반복 4741 / 9295 | 시간 343[s] | 손실 2.36
# | 에폭 1 |  반복 4761 / 9295 | 시간 345[s] | 손실 2.35
# | 에폭 1 |  반복 4781 / 9295 | 시간 346[s] | 손실 2.36
# | 에폭 1 |  반복 4801 / 9295 | 시간 348[s] | 손실 2.39
# | 에폭 1 |  반복 4821 / 9295 | 시간 349[s] | 손실 2.33
# | 에폭 1 |  반복 4841 / 9295 | 시간 351[s] | 손실 2.34
# | 에폭 1 |  반복 4861 / 9295 | 시간 352[s] | 손실 2.37
# | 에폭 1 |  반복 4881 / 9295 | 시간 354[s] | 손실 2.34
# | 에폭 1 |  반복 4901 / 9295 | 시간 355[s] | 손실 2.37
# | 에폭 1 |  반복 4921 / 9295 | 시간 357[s] | 손실 2.36
# | 에폭 1 |  반복 4941 / 9295 | 시간 358[s] | 손실 2.36
# | 에폭 1 |  반복 4961 / 9295 | 시간 360[s] | 손실 2.36
# | 에폭 1 |  반복 4981 / 9295 | 시간 361[s] | 손실 2.37
# | 에폭 1 |  반복 5001 / 9295 | 시간 362[s] | 손실 2.38
# | 에폭 1 |  반복 5021 / 9295 | 시간 364[s] | 손실 2.35
# | 에폭 1 |  반복 5041 / 9295 | 시간 365[s] | 손실 2.39
# | 에폭 1 |  반복 5061 / 9295 | 시간 367[s] | 손실 2.37
# | 에폭 1 |  반복 5081 / 9295 | 시간 368[s] | 손실 2.36
# | 에폭 1 |  반복 5101 / 9295 | 시간 370[s] | 손실 2.36
# | 에폭 1 |  반복 5121 / 9295 | 시간 371[s] | 손실 2.36
# | 에폭 1 |  반복 5141 / 9295 | 시간 373[s] | 손실 2.35
# | 에폭 1 |  반복 5161 / 9295 | 시간 374[s] | 손실 2.40
# | 에폭 1 |  반복 5181 / 9295 | 시간 376[s] | 손실 2.35
# | 에폭 1 |  반복 5201 / 9295 | 시간 377[s] | 손실 2.35
# | 에폭 1 |  반복 5221 / 9295 | 시간 379[s] | 손실 2.35
# | 에폭 1 |  반복 5241 / 9295 | 시간 380[s] | 손실 2.34
# | 에폭 1 |  반복 5261 / 9295 | 시간 382[s] | 손실 2.35
# | 에폭 1 |  반복 5281 / 9295 | 시간 383[s] | 손실 2.34
# | 에폭 1 |  반복 5301 / 9295 | 시간 385[s] | 손실 2.34
# | 에폭 1 |  반복 5321 / 9295 | 시간 386[s] | 손실 2.36
# | 에폭 1 |  반복 5341 / 9295 | 시간 388[s] | 손실 2.36
# | 에폭 1 |  반복 5361 / 9295 | 시간 389[s] | 손실 2.35
# | 에폭 1 |  반복 5381 / 9295 | 시간 391[s] | 손실 2.33
# | 에폭 1 |  반복 5401 / 9295 | 시간 392[s] | 손실 2.33
# | 에폭 1 |  반복 5421 / 9295 | 시간 393[s] | 손실 2.34
# | 에폭 1 |  반복 5441 / 9295 | 시간 395[s] | 손실 2.34
# | 에폭 1 |  반복 5461 / 9295 | 시간 396[s] | 손실 2.35
# | 에폭 1 |  반복 5481 / 9295 | 시간 398[s] | 손실 2.34
# | 에폭 1 |  반복 5501 / 9295 | 시간 399[s] | 손실 2.37
# | 에폭 1 |  반복 5521 / 9295 | 시간 401[s] | 손실 2.34
# | 에폭 1 |  반복 5541 / 9295 | 시간 402[s] | 손실 2.32
# | 에폭 1 |  반복 5561 / 9295 | 시간 404[s] | 손실 2.33
# | 에폭 1 |  반복 5581 / 9295 | 시간 405[s] | 손실 2.35
# | 에폭 1 |  반복 5601 / 9295 | 시간 407[s] | 손실 2.32
# | 에폭 1 |  반복 5621 / 9295 | 시간 408[s] | 손실 2.36
# | 에폭 1 |  반복 5641 / 9295 | 시간 409[s] | 손실 2.30
# | 에폭 1 |  반복 5661 / 9295 | 시간 411[s] | 손실 2.37
# | 에폭 1 |  반복 5681 / 9295 | 시간 412[s] | 손실 2.35
# | 에폭 1 |  반복 5701 / 9295 | 시간 414[s] | 손실 2.31
# | 에폭 1 |  반복 5721 / 9295 | 시간 415[s] | 손실 2.34
# | 에폭 1 |  반복 5741 / 9295 | 시간 417[s] | 손실 2.33
# | 에폭 1 |  반복 5761 / 9295 | 시간 418[s] | 손실 2.31
# | 에폭 1 |  반복 5781 / 9295 | 시간 420[s] | 손실 2.33
# | 에폭 1 |  반복 5801 / 9295 | 시간 421[s] | 손실 2.33
# | 에폭 1 |  반복 5821 / 9295 | 시간 423[s] | 손실 2.36
# | 에폭 1 |  반복 5841 / 9295 | 시간 424[s] | 손실 2.31
# | 에폭 1 |  반복 5861 / 9295 | 시간 425[s] | 손실 2.33
# | 에폭 1 |  반복 5881 / 9295 | 시간 427[s] | 손실 2.33
# | 에폭 1 |  반복 5901 / 9295 | 시간 428[s] | 손실 2.31
# | 에폭 1 |  반복 5921 / 9295 | 시간 430[s] | 손실 2.35
# | 에폭 1 |  반복 5941 / 9295 | 시간 431[s] | 손실 2.29
# | 에폭 1 |  반복 5961 / 9295 | 시간 433[s] | 손실 2.35
# | 에폭 1 |  반복 5981 / 9295 | 시간 434[s] | 손실 2.33
# | 에폭 1 |  반복 6001 / 9295 | 시간 436[s] | 손실 2.32
# | 에폭 1 |  반복 6021 / 9295 | 시간 437[s] | 손실 2.30
# | 에폭 1 |  반복 6041 / 9295 | 시간 439[s] | 손실 2.35
# | 에폭 1 |  반복 6061 / 9295 | 시간 440[s] | 손실 2.32
# | 에폭 1 |  반복 6081 / 9295 | 시간 441[s] | 손실 2.32
# | 에폭 1 |  반복 6101 / 9295 | 시간 443[s] | 손실 2.30
# | 에폭 1 |  반복 6121 / 9295 | 시간 444[s] | 손실 2.32
# | 에폭 1 |  반복 6141 / 9295 | 시간 446[s] | 손실 2.30
# | 에폭 1 |  반복 6161 / 9295 | 시간 447[s] | 손실 2.32
# | 에폭 1 |  반복 6181 / 9295 | 시간 449[s] | 손실 2.33
# | 에폭 1 |  반복 6201 / 9295 | 시간 450[s] | 손실 2.34
# | 에폭 1 |  반복 6221 / 9295 | 시간 452[s] | 손실 2.32
# | 에폭 1 |  반복 6241 / 9295 | 시간 453[s] | 손실 2.31
# | 에폭 1 |  반복 6261 / 9295 | 시간 455[s] | 손실 2.32
# | 에폭 1 |  반복 6281 / 9295 | 시간 456[s] | 손실 2.29
# | 에폭 1 |  반복 6301 / 9295 | 시간 458[s] | 손실 2.34
# | 에폭 1 |  반복 6321 / 9295 | 시간 459[s] | 손실 2.34
# | 에폭 1 |  반복 6341 / 9295 | 시간 460[s] | 손실 2.30
# | 에폭 1 |  반복 6361 / 9295 | 시간 462[s] | 손실 2.30
# | 에폭 1 |  반복 6381 / 9295 | 시간 463[s] | 손실 2.32
# | 에폭 1 |  반복 6401 / 9295 | 시간 465[s] | 손실 2.31
# | 에폭 1 |  반복 6421 / 9295 | 시간 466[s] | 손실 2.28
# | 에폭 1 |  반복 6441 / 9295 | 시간 468[s] | 손실 2.31
# | 에폭 1 |  반복 6461 / 9295 | 시간 469[s] | 손실 2.29
# | 에폭 1 |  반복 6481 / 9295 | 시간 470[s] | 손실 2.30
# | 에폭 1 |  반복 6501 / 9295 | 시간 472[s] | 손실 2.31
# | 에폭 1 |  반복 6521 / 9295 | 시간 473[s] | 손실 2.29
# | 에폭 1 |  반복 6541 / 9295 | 시간 475[s] | 손실 2.32
# | 에폭 1 |  반복 6561 / 9295 | 시간 476[s] | 손실 2.28
# | 에폭 1 |  반복 6581 / 9295 | 시간 478[s] | 손실 2.30
# | 에폭 1 |  반복 6601 / 9295 | 시간 479[s] | 손실 2.31
# | 에폭 1 |  반복 6621 / 9295 | 시간 480[s] | 손실 2.31
# | 에폭 1 |  반복 6641 / 9295 | 시간 482[s] | 손실 2.29
# | 에폭 1 |  반복 6661 / 9295 | 시간 483[s] | 손실 2.29
# | 에폭 1 |  반복 6681 / 9295 | 시간 485[s] | 손실 2.29

# %% [markdown]
# #### 4.3.3 CBOW 모델 평가

# %%
import sys
sys.path.append('exam_code')
from common.util import most_similar
import pickle

pkl_file = 'cbow_params.pkl'

with open(pkl_file, 'rb') as f:
    params = pickle.load(f)
    word_vecs  = params['word_vecs']
    word_to_id = params['word_to_id']
    id_to_word = params['id_to_word']
    
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
    most_similar(query, word_to_id, id_to_word, word_vecs, top=5)

# %%
import sys
sys.path.append('exam_code')
from common.util import analogy

analogy('king', 'man', 'queen', word_to_id, id_to_word, word_vecs)
analogy('take', 'took', 'go', word_to_id, id_to_word, word_vecs)
analogy('car', 'cars', 'child', word_to_id, id_to_word, word_vecs)
analogy('good', 'better', 'bad', word_to_id, id_to_word, word_vecs)
